# %%
hi how are you

# %%
names=['Ramesh','Suresh','Satish']
age=[20,25,30]
# 'Ramesh age is 20'
# 'Suresh age is 25'

# %%
names=['Ramesh','Suresh','Satish']
age=[20,25,30]
for i in range(len(names)):
    print("{names[i]} age is {age[i]}")
# Out:
# {names[i]} age is {age[i]}
# {names[i]} age is {age[i]}
# {names[i]} age is {age[i]}

# %% [markdown]
# **Zip**

# %%
names=['Ramesh','Suresh','Satish']
age=[20,25,30]
for i,j in zip(names,age):
    print(i,j)
    print(f"{i} age is {j}")
# Out:
# Ramesh 20
# Ramesh age is 20
# Suresh 25
# Suresh age is 25
# Satish 30
# Satish age is 30

# %%
names=['Ramesh','Suresh','Satish']
age=[20,25,30]
for i,j in zip(names,age):
    print(j)
# Out:
# 20
# 25
# 30

# %% [markdown]
# **Dictionary**
#
# - in above example names and age both are together
# - when both are together we can pair them
# - this can happen using Dictionary
# - Dictionary is calles as **key-value** pair
# - it represents with curly braces:**{key:value}**
# - ramesh and 20 years both are pair:{'Ramesh':20}

# %%
d1={'Ramesh':20,'Suresh':25,'Satish':30}
d1
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'Satish': 30}

# %%
d2={20:'Ramesh',25:'Suresh',30:'Satish'}
d2
# Out:
# {20: 'Ramesh', 25: 'Suresh', 30: 'Satish'}

# %%
# start your imagination make a dictionary with many ways

d1={'Ramesh':20,'Suresh':25,'Satish':30}
d2={20:'Ramesh',25:'Suresh',30:'Satish'}
d3={'Ramesh':'20','Suresh':'25','Satish':30}
d4={'20':'Ramesh','25':'Suresh',30:'Satish'}
d5={'Ramesh':20,'Ramesh':30}
d6=

# %%
**list as keys fails because list has amutable behaviour**
**tuple as keys works because tuple has immutable behaviour**
**in dictionary keys are very very important**
**keys does not change so when we apply list is fail in**

# %%
d14={'Fruites':{'Apple':20}}  #works
d15={{'Apple':20}:'Fruites'}  #fails
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 d14={'Fruites':{'Apple':20}}  #works
# ----> 2 d15={{'Apple':20}:'Fruites'}
#
# TypeError: unhashable type: 'dict'

# %%
dict1={'Apple':20,'Banana':30,'Cherry':50}
dict2={'Apple':20,'apple':30}
dict3={20:'Apple',30:'Banana',50:'Cherry'}
#appd1ly min max sorted reverse
d1={'Apple':20,'Banana':30,'Cherry':50}
d2={'Apple':20,'apple':30}
d3={20:'Apple',30:'Banana',50:'Cherry'}
max(d1),max(d2),max(d3)
# Out:
# ('Cherry', 'apple', 50)

# %%
min(d1),min(d2),min(d3)
# Out:
# ('Apple', 'Apple', 20)

# %%
#dict1={'Apple':20,'Banana':30,'Cherry':10}
'Apple':20
'Banana':30
'Cherry':10
# Out:
#   Cell In[21], line 2
#     'Apple':20
#     ^
# SyntaxError: illegal target for annotation

# %%
dict1={'Apple':20,'Banana':30,'Cherry':10}
dict[0]

#'Apple':20 in dict1
# Out:
# dict[0]

# %%
**how to extract the values**
- in dictionary we have a concept key:value pair
-

# %%
dict1={'Apple':20,'Banana':30,'Cherry':10}
dict1['Apple']
dict1['Banana']
dict1['Cherry']

# %%
for

# %%
#names=['Ramesh','Suresh','Satish']
#age=[20,25,30]
#'Ramesh age is 20'
#'Suresh age is 25'
names={'Ramesh':20,'Suresh':25,'Satish':30}
for key in names:
    value=names[key]
    print(f'{key}age is {value}')
# Out:
# Rameshage is 20
# Sureshage is 25
# Satishage is 30

# %%
d={'Fruites':['Apple','Banana','Cherry']}
#get cherry
d['Fruites'][2]
# Out:
# 'Cherry'

# %%
d={'Fruites':['Apple':['sweet','sour','green']]}
d
# identify how many key-value pairs
d['Fruites'] #dictionary
d['Fruites']['Apple'][2]
# Out:
#   Cell In[32], line 1
#     d={'Fruites':['Apple':['sweet','sour','green']]}
#                          ^
# SyntaxError: invalid syntax

# %%
d={'Fruites':[{'Cost':[50]}]}
d['Fruites'] # list
d['Fruites'][0] # dict
d['Fruites'][0]['Cost'] #list
d['Fruites'][0]['Cost'][0]
# Out:
# 50

# %%
d={'Fruites':['Apple'],'Cost':[{'1kg':[20,30,40],'2kg':None}]}
len(d)
len(d['Cost'])
d['Cost'][0]['2kg']
d['Cost'][0]['1kg'][2]
# Out:
# 40

# %%
d={'Fruites':{'Orange':{'Nagpur':{'MH':{'King':{'Shivaji':{'Shambaji'}}}}}}}
d['Fruites']['Orange']['Nagpur']['MH']['King']['Shivaji'] #
#do it sets today tomorrow shambaji
# Out:
# {'Shambaji'}

# %% [markdown]
# **how to create empty dictionary**
#
# - Now onwards focus on creation of empty list,strings and dictionary
#
# - we will take empty list will use append operation
#
# - we will take empty string will use concatenation
#
# - we will take empty dictionary will use key:value pair concept

# %%
# list
l=[]
l.append(10)
l.append(20)
l
# Out:
# [10, 20]

# %%
# strings
s=''
s=s+'p' # ''+'p'
s=s+'y' # 'p'+'y'='py'
s
# Out:
# 'py'

# %%
# dictionary
d={}
d['Ramesh']=20
d['Suresh']=25
d['satish']=30
d
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'satish': 30}

# %%
d={}
d['Ramesh']=20
d['Suresh']=25
d['satish']=30
# d[key]=value
# d[i]=j

# %% [markdown]
# **how to convert list to dictionary**

# %%
names=['Ramesh','Suresh','Satish'] #i
age=[20,25,30] #j
dict1={}
for i,j in zip(names,age):
    dict1[i]=j
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'Satish': 30}

# %% [markdown]
# **dictionary comprehension**

# %% [markdown]
# - for list comprehension we written everything inside list
# - for dict comprehension we should write evrything inside list

# %%
# list comprehension: [<output><for loop>]
# dict comprehension: {key:value<for loop>}

# %%
names=['Ramesh','Suresh','Satish'] #i
age=[20,25,30] #j
{i:j for i,j in zip(names,age)}
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'Satish': 30}

# %% [markdown]
# **mutable-immutable**

# %% [markdown]
# - lists are mutable
# - dictionary are also mutable
# - srings are mutable
# - tuple immutable
# - in dictionary we can change the values using keys

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
d['Ramesh']=30
d
# Out:
# {'Ramesh': 30, 'Suresh': 25, 'Satish': 30}

# %% [markdown]
# **methods**

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d={'Fruites':{'Apple':['sweet','sour','green']}}
d['Fruites']
d['Fruites']['Apple']
d['Fruites']['Apple'][2]
# Out:
# 'green'

# %%
d={'Fruites':[{'Cost':[50]}]}
d['Fruites']
d['Fruites'][0]
d['Fruites'][0]['Cost']
d['Fruites'][0]['Cost'][0]
# Out:
# 50

# %%
d={'Fruites':['Apple'],'Cost':[{'1kg':[20,30,40],'2kg':None}]}
len(d)
len(d['Cost'])
print(d['Cost'][0]['1kg'][2])
print(d['Cost'][0]['2kg'])
# Out:
# 40
# None

# %%
d={'Fruites':{'Orange':{'Nagpur':{'MH':{'King':{'Shivaji':{'Shambaji'}}}}}}}
Shambaji=d['Fruites']['Orange']['Nagpur']['MH']['King']['Shivaji']['Shambaji']
print('Shambaji')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 d={'Fruites':{'Orange':{'Nagpur':{'MH':{'King':{'Shivaji':{'Shambaji'}}}}}}}
# ----> 2 Shambaji=d['Fruites']['Orange']['Nagpur']['MH']['King']['Shivaji']['Shambaji']
#       3 print('Shambaji')
#
# TypeError: 'set' object is not subscriptable

# %%
print('Shambaji')
# Out:
# Shambaji

# %% [markdown]
# **keys**

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
keys=d.keys()
keys
# Out:
# dict_keys(['Ramesh', 'Suresh', 'Satish'])

# %%
type(keys)
# Out:
# dict_keys

# %%
# i got mistake im assuming this is list type
keys.count('Ramesh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # i got mistake im assuming this is list type
# ----> 2 keys.count('Ramesh')
#
# AttributeError: 'dict_keys' object has no attribute 'count'

# %% [markdown]
# **Convert dictionary to list**
#
# - in order to convert dictionary to list
#
# - first we need to seperate keys and values
#
# - then apply list type casting

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
keys=d.keys()
keys_list=list(keys)
keys_list
# Out:
# ['Ramesh', 'Suresh', 'Satish']

# %%
list===string    #using join
string===list    #using split
list===dict       #zip
dict===list       #typecasting

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
values=d.values()
values_list=list(values)
values_list
# Out:
# [20, 25, 30]

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
items=d.items()
items_list=list(items)
items_list
# Out:
# [('Ramesh', 20), ('Suresh', 25), ('Satish', 30)]

# %%
type(keys_list),type(keys)
# Out:
# (list, dict_keys)

# %%
keys_list.count('Ramesh')
# Out:
# 1

# %%
['Ramesh':20]
# Out:
#   Cell In[10], line 1
#     ['Ramesh':20]
#              ^
# SyntaxError: invalid syntax

# %%
# input='virat.kohli@rcb.com;rohit.sharma@mi.com;ms.dhoni@csk.com'
# output={'Firstname':['virat','rohit','ms'],
#         'secondname':[kohli','shrma','dhoni'],
#         'cname':['rcb','mi','csk']}

# idea : first convert string to list
#        from there extract 3 lists
#        1) fname 2) sname 3) cname
#        from three lists create dictionary

input='virat.kohli@rcb.com;rohit.sharma@mi.com;ms.dhoni@csk.com'
l1=input.split(';')
#######################################################
fname,sname,cname=[],[],[]
d={}
for i in l1:
    first_dot=i.index('.')
    second_dot=i.index('.',first_dot+1)
    at_the_rate=i.index('@')
    fname.append(i[:first_dot])
    sname.append(i[first_dot+1:at_the_rate])
    cname.append(i[at_the_rate+1:second_dot])
########################################################
d['Fname']=fname
d['Sname']=sname
d['Cname']=cname
d
# Out:
# {'Fname': ['virat', 'rohit', 'ms'],
#  'Sname': ['kohli', 'sharma', 'dhoni'],
#  'Cname': ['rcb', 'mi', 'csk']}

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# **pop-popitem**

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
d.pop('Ramesh')
# Out:
# 20

# %%
d
# Out:
# {'Suresh': 25, 'Satish': 30}

# %%
l1=['Ramesh','Suresh','Satish']
l1.remove('Ramesh')
l1
# Out:
# ['Suresh', 'Satish']

# %%
l1=['Ramesh','Suresh','Satish']
l1.pop()
l1
# Out:
# ['Ramesh', 'Suresh']

# %% [markdown]
# **pop** in dictionary,similar analogy **remove** in list
#
# **pop item** in dictionary,similar analogy **pop** in list

# %% [markdown]
# **get**

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
d.get('Ramesh')
# Out:
# 20

# %%
d['Ramesh']  #key as an index
# Out:
# 20

# %% [markdown]
# **update**

# %% [markdown]
# - update is similar analogy **list extend**
# - take two dictionarys and apply update method

# %%
d1={'Ramesh':20,'Suresh':25,'Satish':30}
d2={'Manish':20,'Mahesh':25,'Saresh':30}
d1.update(d2)
d1
# Out:
# {'Ramesh': 20,
#  'Suresh': 25,
#  'Satish': 30,
#  'Manish': 20,
#  'Mahesh': 25,
#  'Saresh': 30}

# %%
l1=['Ramesh','Suresh','Satish']
l2=[20,30,40]
l1.extend(l2)
l1
# Out:
# ['Ramesh', 'Suresh', 'Satish', 20, 30, 40]

# %% [markdown]
# - **update in dictionary**,similar analogy **list extend**

# %% [markdown]
# **setdefault**
#
# - suppose an already existed dictionary available
#
# - we can update the dictionary with new key:value pair

# %%
d1={'Ramesh':20,'Suresh':25,'Satish':30}
d1.setdefault('Manish')
d1.setdefault('Mahesh',35)
d1
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'Satish': 30, 'Manish': None, 'Mahesh': 35}

# %% [markdown]
# - **setdefault** in dictionary, similar analogy **list append**
# - always remember dictionary is a key:value pair concept
# - it never involves index operations
# - that why we dont have any index or find methods
# - we have get method to extract values using key

# %% [markdown]
# **fromkeys**
#
# - create a dictionary with different keys but same value
#
# - fromkeys will take an argument **iterable**
#
# - try to provide an iterator i.e string,list,tuple

# %%
d={}
names=['Ramesh','Suresh','Satish']
d.fromkeys(names,'NareshIT')
# Out:
# {'Ramesh': 'NareshIT', 'Suresh': 'NareshIT', 'Satish': 'NareshIT'}

# %%
d={}
d.fromkeys('python')
# Out:
# {'p': None, 'y': None, 't': None, 'h': None, 'o': None, 'n': None}

# %%
- **pop** in dictionary,similar analogy **remove** in list
- **popitem** in  dictionary ,similar analogy **pop** in list
- **update in dictionary**,similar analogy **list extend**
-
